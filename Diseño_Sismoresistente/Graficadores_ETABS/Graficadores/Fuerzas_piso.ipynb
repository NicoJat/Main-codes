# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the Excel file into a DataFrame
file_path_X = '../Resultados_Excel/Fuerzas_X.xlsx'  # Replace with your file path
file_path_Y = '../Resultados_Excel/Fuerzas_Y.xlsx'  # Replace with your file path
sheet_name = 'Story Response'  # Replace with your sheet name if different

# Load the data into a DataFrame
data_X = pd.read_excel(file_path_X, sheet_name=sheet_name, header=1)
data_Y = pd.read_excel(file_path_Y, sheet_name=sheet_name, header=1)

# Assuming your data has 'Node' and 'Displacement' columns
# Replace these column names with your actual column names
FCX = data_X['X-Dir']
FCX = [float(item) for item in FCX[1:]]
FCY = data_Y['Y-Dir']
FCY = [float(item) for item in FCY[1:]]

Pisos = np.arange(34, 0, -1)
#Pisos = [str(node) for node in Pisos]
Pisos = [int(item) for item in Pisos]

data = {
    'Pisos': Pisos,
    'FCX': FCX,
    'FCY': FCY
}

df = pd.DataFrame(data)
display(df)
# Out:
#     Pisos         FCX         FCY
# 0      34  165.032928  165.032928
# 1      33  214.952375  214.952375
# 2      32  208.315767  208.315767
# 3      31  201.679158  201.679158
# 4      30  195.042550  195.042550
# 5      29  188.405941  188.405941
# 6      28  272.715114  272.715114
# 7      27  296.659931  296.659931
# 8      26  285.418081  285.418081
# 9      25  274.176231  274.176231
# 10     24  262.934381  262.934381
# 11     23  251.692531  251.692531
# 12     22  308.528664  308.528664
# 13     21  325.931960  325.931960
# 14     20  309.946196  309.946196
# 15     19  293.960432  293.960432
# 16     18  277.974669  277.974669
# 17     17  261.988905  261.988905
# 18     16  246.003141  246.003141
# 19     15  230.017378  230.017378
# 20     14  214.031614  214.031614
# 21     13  272.431162  272.431162
# 22     12  252.638156  252.638156
# 23     11  208.216955  208.216955
# 24     10  187.395259  187.395259
# 25      9  166.573564  166.573564
# 26      8  145.751868  145.751868
# 27      7  124.930173  124.930173
# 28      6  104.108477  104.108477
# 29      5   83.286782   83.286782
# 30      4   62.465086   62.465086
# 31      3   39.488090   39.488090
# 32      2   15.741681   15.741681
# 33      1    0.000000    0.000000

# %%
FCX_array = np.array(FCX)
# Plotting the forces as arrows
plt.figure(figsize=(6, 8))
plt.quiver(FCX_array, Pisos, -FCX_array, np.zeros_like(Pisos), scale=1, scale_units='xy', angles='xy')
plt.xlabel('Fuerza en T')
plt.ylabel('Pisos')
plt.grid('on')
plt.show()

# %%
FCY_array = np.array(FCY)
# Plotting the forces as arrows
plt.figure(figsize=(6, 8))
plt.quiver(FCY_array, Pisos, -FCY_array, np.zeros_like(Pisos), scale=1, scale_units='xy', angles='xy')
plt.xlabel('Fuerza en T')
plt.ylabel('Pisos')
plt.grid('on')
plt.show()
