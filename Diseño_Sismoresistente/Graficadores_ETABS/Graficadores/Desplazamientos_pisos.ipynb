# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the Excel file into a DataFrame
file_path_X = '../Resultados_Excel/Desplazamientos_piso_X.xlsx'  # Replace with your file path
file_path_Y = '../Resultados_Excel/Desplazamientos_piso_Y.xlsx'  # Replace with your file path
sheet_name = 'Story Response'  # Replace with your sheet name if different

# Load the data into a DataFrame
data_X = pd.read_excel(file_path_X, sheet_name=sheet_name, header=1)
data_Y = pd.read_excel(file_path_Y, sheet_name=sheet_name, header=1)

# Assuming your data has 'Node' and 'Displacement' columns
# Replace these column names with your actual column names
Desp_piso_X = data_X['X-Dir']
Desp_piso_Y = data_Y['Y-Dir']
nodes = np.arange(34, 0, -1)
nodes_str = [str(node) for node in nodes]

data = {
    'Pisos': nodes_str,
    'Desp_CM_X': Desp_piso_X[1:],
    'Desp_CM_Y': Desp_piso_Y[1:]
}

df = pd.DataFrame(data)
display(df)

# Plotting
plt.figure(figsize=(8, 10))
plt.plot(Desp_piso_X[1:], nodes_str, marker='o', linestyle='-', label='Desp_piso_X')
plt.plot(Desp_piso_Y[1:], nodes_str, marker='o', linestyle='-', label='Desp_piso_Y')
plt.xlabel('Desplazamientos piso en m')
plt.ylabel('Pisos')
plt.title('Desplazamientos del piso')
plt.legend()
plt.grid(True)
plt.gca().invert_yaxis()
plt.show()
# Out:
#    Pisos Desp_CM_X Desp_CM_Y
# 1     34  0.084294  0.080529
# 2     33  0.081643  0.078241
# 3     32   0.07885  0.075839
# 4     31  0.075909  0.073322
# 5     30  0.072836    0.0707
# 6     29  0.069683  0.067993
# 7     28  0.068189  0.073674
# 8     27  0.065225  0.070691
# 9     26  0.062246  0.067668
# 10    25  0.059233  0.064601
# 11    24  0.056197  0.061499
# 12    23  0.053153  0.058375
# 13    22  0.050905  0.061175
# 14    21  0.047922  0.057855
# 15    20  0.044936  0.054506
# 16    19  0.041948  0.051131
# 17    18  0.038969  0.047735
# 18    17  0.036009  0.044327
# 19    16  0.033077  0.040918
# 20    15  0.030185  0.037519
# 21    14  0.027346  0.034145
# 22    13  0.024681  0.033069
# 23    12  0.020978  0.028245
# 24    11  0.018411  0.024869
# 25    10  0.015926  0.021576
# 26     9  0.013554  0.018381
# 27     8   0.01153    0.0153
# 28     7  0.009525  0.012357
# 29     6   0.00756  0.009577
# 30     5  0.005655  0.006988
# 31     4  0.003835  0.004626
# ...
