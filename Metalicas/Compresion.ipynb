# %%
import numpy as np

'''
El siguiente programa es desarrollado sin fines de lucro con el fin de 
realizar un prediseño para columnas de acero, comprobando su resistencia ante
carga axial y flexion segun la AISC 360-16.

¡¡Aviso!!: Calcular con anticipacion las propiedades de la seccion con la ayuda de 
los programas secundarios. Por lo pronto seguimos desarrollando la automatizacion.
'''

print('PROGRAMA PARA DISEÑO A COMPRESION ESTRUCTURAS DE ACERO')
print('PONTIFICIA UNIVERSIDAD CATOLICA DEL ECUADOR')
print('Derechos: Nicolas Fernando Játiva Palma')

#INSERCION DE DATOS INICIALES
E=2040000   #Modulo de elasticidad  kg/cm2
fy=2530 #Esfuerzo de fluencia kg/cm2
fu=4200 #Esfuerzo ultimo  kg/cm2


#Declaracion de datos: W10 x 30
'''
class propseccioni:
    def Propiedades(d,tw,tf,b):
        d = 30
        tw = 0.3
        tf = 0.51
        b = 5.81

        
        bf1 = b
        tf1 = tf
        bf2 = b
        tf2 = tf
        hw = d - (tf1 + tf2)

        area = (bf1*tf1)+(bf2*tf2)+(tw*hw) 
        centroidxi = (np.max(bf1,bf2)*0.5)
        centroidyi = (((tf2/2)*(bf2*tf2))+((tf2+(hw/2))*(tw*hw))+((tf2+hw+(tf1/2))*(bf1*tf1)))/area
        inerciaxi = (((bf1*(tf1**3)/12))+(bf1*tf1*np.abs(((tf2+(tf1/2)+hw-centroidyi)**2)))) + ((tw*(hw**3)/12)+(hw*tw*np.abs(((tf2+(hw/2)-centroidyi))**2))) + ((bf2*(tf2**3)/12)+(bf2*tf2*(centroidyi-(tf2/2))**2))
        inerciayi = (((tf1*(bf1**3)/12))) + ((hw*(tw**3)/12)) + ((tf2*(bf2**3)/12))
        inerciapi = inerciaxi + inerciayi
        x0i = np.max((bf1/2),(bf2/2))
        y0i = (tf1*(bf1**3)*hw)/((tf1*(bf1**3))+(tf2*(bf2**3)))
        rxi = np.sqrt(inerciaxi/area)
        ryi = np.sqrt(inerciayi/area)
        cwi = ((hw**2)*tf1*(bf1**3)*(bf2**3))/(12*((bf1**3)+(bf2**3)))

        return area, centroidxi, centroidyi, inerciaxi, inerciayi, inerciapi, x0i, y0i, rxi, ryi, cwi


E = 2040000 #kg/cm2
L = [1,2,3,4]
A = [propseccioni.area, propseccioni.area,, propseccioni.area, propseccioni.area]
I = [propseccioni.inerciaxi, propseccioni.inerciaxi,, propseccioni.inerciaxi, propseccioni.inerciaxi]
'''
########################################################


#Evaluacion de esbeltez

c=float(input('Especifique caso (Casos disponibles 1-9) segun Tabla B4-1a: '))

if c==1:
    b=float(input('Indicar b: '))   
    t=float(input('Indicar t: '))   #Espesor ala y alma
    lmb=b/t
    lmbr=0.56*(np.sqrt((E/fy)))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==2:
    b=float(input('Indicar b: '))
    tf=float(input('Indicar tf: '))  #Espesor del ala
    h=float(input('Indicar h: '))
    tw=float(input('Indicar tw: '))   #Espesor del alma
    kc=4/(np.sqrt(h/tw))
    if kc<0.35:
        kc=0.35
    elif kc>0.75:
        kc=0.75
    else:
        kc=4/(np.sqrt(h/tw))

    lmb=b/tf
    lmbr=0.64*(np.sqrt((kc*E/fy)))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==3:
    b=float(input('Indicar b: '))   
    t=float(input('Indicar t: '))   #Espesor ala y alma
    lmb=b/t
    lmbr=0.45*(np.sqrt(E/fy))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==4:
    d=float(input('Indicar d: '))   
    t=float(input('Indicar t: '))   #Espesor
    lmb=d/t
    lmbr=0.75*(np.sqrt(E/fy))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==5:
    h=float(input('Indicar h: '))   
    t=float(input('Indicar t: '))   #Espesor alma
    lmb=h/t
    lmbr=1.49*(np.sqrt(E/fy))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==6:
    b=float(input('Indicar b: '))   
    t=float(input('Indicar t: '))   #Espesor ala y alma
    lmb=b/t
    lmbr=1.4*(np.sqrt(E/fy))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==7:
    b=float(input('Indicar b: '))   
    t=float(input('Indicar t: '))   #Espesor ala y alma
    lmb=b/t
    lmbr=1.40*(np.sqrt(E/fy))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==8:
    b=float(input('Indicar b: '))   
    t=float(input('Indicar t: '))  
    lmb=b/t
    lmbr=1.49*(np.sqrt(E/fy))
    if lmb>lmbr:
        scs='Slender'
    else:
        scs='non-slender'
elif c==9:
    D=float(input('Indicar D: '))   
    t=float(input('Indicar t: '))   
    lmb=D/t
    lmbr=0.11*(E/fy)
    if lmb>lmbr:
        scs='slender'
    else:
        scs='non-slender'


#Calculo de propiedades de la seccion

Ag=182.4 #float(input('Especifique el area bruta de la seccion (cm2): '))
Ix=44940.8 #float(input('Especifique la inercia en x de la seccion (cm4): '))
Iy=15556.61 #float(input('Especifique la inercia en y de la seccion (cm4): '))
G=787220.92 #En kgf/cm2

Kx=1 #float(input('Especifique Kx de la seccion: '))
Ky=1 #float(input('Especifique Ky de la seccion: '))
Kz=1 #float(input('Especifique Kz de la seccion: '))
L=350  #float(input('Especifique L (cm), (E3) (longitud no arriostrada longitudinalmente): '))
J=Ix+Iy #en cm4
rx=np.sqrt(Ix/Ag)
ry=np.sqrt(Iy/Ag)
In=np.minimum(Ix,Iy)
K=np.minimum(Kx,Ky)
r=np.minimum(rx,ry)

'''
Establecemos aqui las funciones E3, E4, E5, E6 y E7
correspondientes a cada capitulo de la AISC 360-16.
'''


def E3(K,L,r,Ag,E,fy,In):
    Fe = (((np.pi)**2)*E)/((K*L/r)**2)
    if ((K*L)/r)>(4.71*np.sqrt(E/fy)) or (fy/Fe)>2.25:
        e3Fcr = 0.877*Fe
    elif ((K*L)/r)<=(4.71*np.sqrt(E/fy)):
        e3Fcr = (0.658**(fy/Fe))*fy
    
    e3Pn=e3Fcr*Ag
    e3phiPn=0.9*e3Pn
    return e3Pn, e3phiPn, e3Fcr


def E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In):
    cso=input('Especifique caso de la seccion E4 (a,b o c):')
    if cso=='a':
        h0 = float(input('Especifique h0, la distancia entre centroides de las alas: '))
        Cw = (Iy*(h0**2))/4
        Lz = float(input('Especifique Lz de la seccion (cm): '))
        Kz = 1 #float(input('Especifique Kz de la seccion: '))
        Fe = ((((np.pi**2)*E*Cw)/((Kz*Lz)**2))+(G*J))/(Ix+Iy)
        if ((K*L)/r)>(4.71*np.sqrt(E/fy)) or (fy/Fe)>2.25:
            e4Fcr = 0.877*Fe
        elif ((K*L)/r)<=(4.71*np.sqrt(E/fy)):
            e4Fcr = (0.658**(fy/Fe))*fy
        
        e4Pn=e4Fcr*Ag
        e4phiPn=0.9*e4Pn
    elif cso=='b':
        x0= 18 #float(input('Especifique x0 (cm): '))
        y0= 12 #float(input('Especifique y0 (cm): '))
        r0=np.sqrt((x0**2)+(y0**2)+((Ix+Iy)/Ag))
        H=1-(((x0**2)+(y0**2))/(r0**2))
        Cw=float(input('Especifique Cw (cm6): '))
        Lz = float(input('Especifique Lz de la seccion (cm): '))
        Ly = float(input('Especifique Ly de la seccion (cm): '))
        Fey = (((np.pi)**2)*E)/((Ky*Ly/ry)**2)
        Fez = ((((np.pi**2)*E*Cw)/((Kz*Lz)**2))+(G*J))/(Ag*(r0**2))
        Fe=((Fey+Fez)/(2*H))*(1-(np.sqrt(1-((4*Fey*Fez*H)/((Fey+Fez)**2)))))
        if ((K*L)/r)>(4.71*np.sqrt(E/fy)) or (fy/Fe)>2.25:
            e4Fcr = 0.877*Fe
        elif ((K*L)/r)<=(4.71*np.sqrt(E/fy)):
            e4Fcr = (0.658**(fy/Fe))*fy
    
        e4Pn=e4Fcr*Ag
        e4phiPn=0.9*e4Pn
    elif cso=='c':
        x0= 18 #float(input('Especifique x0 (cm): '))
        y0= 12 #float(input('Especifique y0 (cm): '))
        r0=np.sqrt((x0**2)+(y0**2)+((Ix+Iy)/Ag))
        H=1-(((x0**2)+(y0**2))/(r0**2))
        Cw=float(input('Especifique Cw (cm6): '))
        Lx = float(input('Especifique Lx de la seccion (cm): '))
        Ly = float(input('Especifique Ly de la seccion (cm): '))
        Lz = float(input('Especifique Lz de la seccion (cm): '))
        Fex = (((np.pi)**2)*E)/((Kx*Lx/rx)**2)
        Fey = (((np.pi)**2)*E)/((Ky*Ly/ry)**2)
        Fez = ((((np.pi**2)*E*Cw)/((Kz*Lz)**2))+(G*J))/(Ag*(r0**2))
        a1=1-((x0**2)/(r0**2))-((y0**2)/(r0**2))
        b1=Fex+Fey+Fez+((Fey*(x0**2))/(r0**2))+((Fey*(y0**2))/(r0**2))
        c1=(Fey*Fez)+(Fex*Fez)
        d1=(Fex*Fey*Fez)
        coeff=[a1, -b1, c1, -d1]
        Fe=np.amin(np.roots(coeff))
        if ((K*L)/r)>(4.71*np.sqrt(E/fy)) or (fy/Fe)>2.25:
            e4Fcr = 0.877*Fe
        elif ((K*L)/r)<=(4.71*np.sqrt(E/fy)):
            e4Fcr = (0.658**(fy/Fe))*fy
    
        e4Pn=e4Fcr*Ag
        e4phiPn=0.9*e4Pn


    return e4Pn, e4phiPn, e4Fcr


def E7(Fcr,fy,E,D,t,Ag,c,lmb,lmbr,b):

    if c == 9:
        if (D/t) <= (0.11*(E/fy)):
            Ae=Ag
        elif (0.11*(E/fy))<(D/t) and (D/t)<(0.45*(E/fy)):
            Ae=(((0.038*E)/(fy*(D/t)))+(2/3))*Ag
        
        ePn=Fcr*Ae
        ephiPn=0.9*ePn
        print('Los siguientes valores consideran el Area efectiva debido a pandeo local')
        print(ePn)
        print(ephiPn)
    else: 
        if c==5 or c==7 or c==8 or c==9:
            c1=0.18
        elif c==6:
            c1=0.2
        else:
            c1= 0.22
        
        c2=(1-(np.sqrt(1-(4*c1))))/(2*c1)
        Fel = ((c2*(lmbr/lmb))**2)*fy

        if lmb<=lmbr*(np.sqrt(fy/Fcr)):
            be=b
        elif lmb>(lmbr*np.sqrt(fy/Fcr)):
            be=b*(1-(c1*np.sqrt(Fel/Fcr)))*(np.sqrt(Fel/Fcr))
        
        Ae=(b-be)*t
        ePn=Fcr*Ae
        ephiPn=0.9*ePn
        print('Los siguientes valores consideran el Area efectiva debido a pandeo local')
        print(ePn)
        print(ephiPn)
  
        
#E3(K,L,r,Ag,E,fy,In)
#E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)

'''
En este apartado las secciones se encuentran
ordenadas secuencialmente segun la tabla E1.1.
especificar caso con2 la enumeracion corresponiente (1-9)
'''

#Calculo de resistencia flexo-compresion de la columna
cs=float(input('Especifique caso (1-9) en tabla E1.1: '))
if cs==1:
    if scs=='non-slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Pn=np.minimum(e3Pn,e4Pn)
        phiPn=np.minimum(e3phiPn,e4phiPn)
        print('Pn es: ',Pn)
        print('phiPn es: ',phiPn)
    elif scs=='slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Fcr=np.minimum(e3Fcr,e4Fcr)
        E7(Fcr,fy,E,D,t,Ag,c,lmb,lmbr,b)
elif cs==2:
    if scs=='non-slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Pn=np.minimum(e3Pn,e4Pn)
        phiPn=np.minimum(e3phiPn,e4phiPn)
        print('Pn es: ',Pn)
        print('phiPn es: ',phiPn)
    elif scs=='slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Fcr=np.minimum(e3Fcr,e4Fcr)
        E7(Fcr,fy,E,D,t,Ag,c,lmb,lmbr,b)
elif cs==3:
    if scs=='non-slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        print('Pn es: ',e3Pn)
        print('phiPn es: ',e3phiPn)
    elif scs=='slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Fcr=np.minimum(e3Fcr,e4Fcr)
        E7(Fcr,fy,E,D,t,Ag,c,lmb,lmbr,b)
elif cs==4:
    if scs=='non-slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        print('Pn es: ',e3Pn)
        print('phiPn es: ',e3phiPn)
    elif scs=='slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Fcr=np.minimum(e3Fcr,e4Fcr)
        E7(Fcr,fy,E,D,t,Ag,c,lmb,lmbr,b)
elif cs==5:
    if scs=='non-slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Pn=np.minimum(e3Pn,e4Pn)
        phiPn=np.minimum(e3phiPn,e4phiPn)
        print('Pn es: ',Pn)
        print('phiPn es: ',phiPn)
    elif scs=='slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Fcr=np.minimum(e3Fcr,e4Fcr)
        E7(Fcr,fy,E,D,t,Ag,c,lmb,lmbr,b)
elif cs==6:
    if scs=='non-slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Pn=np.minimum(e3Pn,e4Pn)
        phiPn=np.minimum(e3phiPn,e4phiPn)
        print('Pn es: ',Pn)
        print('phiPn es: ',phiPn)
        #E6()
    elif scs=='slender':
        print('Descuide, seguimos trabajando en ello')
        #E6()
        #E7()
elif cs==7:
    if scs=='non-slender':
        print('Descuide, seguimos trabajando en ello')
        #E5()
    elif scs=='slender':
        print('Descuide, seguimos trabajando en ello')
        #E5()
elif cs==8:
    e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
    e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
    Pn=np.minimum(e3Pn,e4Pn)
    phiPn=np.minimum(e3phiPn,e4phiPn)
    print('Pn es: ',Pn)
    print('phiPn es: ',phiPn)
elif cs==9:
    if scs=='non-slender':
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        print('Pn es: ',e4Pn)
        print('phiPn es: ',e4phiPn)
    elif scs=='slender':
        e3Pn, e3phiPn, e3Fcr=E3(K,L,r,Ag,E,fy,In)
        e4Pn, e4phiPn, e4Fcr=E4(Kx,Ky,Kz,G,J,rx,ry,K,L,r,Ag,E,fy,In)
        Fcr=np.minimum(e3Fcr,e4Fcr)
        E7(Fcr,fy,E,D,t,Ag,c,lmb,lmbr,b)
# Out:
# PROGRAMA PARA DISEÑO A COMPRESION ESTRUCTURAS DE ACERO
# PONTIFICIA UNIVERSIDAD CATOLICA DEL ECUADOR
# Derechos: Nicolas Fernando Játiva Palma
# Pn es:  427895.97277783125
# phiPn es:  385106.37550004816
