# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

r = np.zeros(1001)
theta = np.linspace(0, 360*15, 1001)
r[0] = 1
r[1] = 2
for i in range(1,1000):
    r[i+1] = r[i] + r[i-1]


df = pd.DataFrame({'r': r, 'theta': theta})
display(df)

plt.polar(theta, r)
# Out:
#                   r   theta
# 0      1.000000e+00     0.0
# 1      2.000000e+00     5.4
# 2      3.000000e+00    10.8
# 3      5.000000e+00    16.2
# 4      8.000000e+00    21.6
# ...             ...     ...
# 996   1.660275e+208  5378.4
# 997   2.686381e+208  5383.8
# 998   4.346656e+208  5389.2
# 999   7.033037e+208  5394.6
# 1000  1.137969e+209  5400.0
#
# [1001 rows x 2 columns]
